# %%
import pandas as pd
import numpy as np
import requests
from datetime import datetime, timezone, timedelta
from io import StringIO
import geohash2
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import math
# Gloabl seaborn Theme
sns.set_theme(style="whitegrid", palette="pastel")
import import_ipynb
import pm25_nowcast_aqi as aqi
# Out:
# importing Jupyter notebook from pm25_nowcast_aqi.ipynb
# PM25: 35.9 AQI: 102

# %% [markdown]
# ## Extraction - PM25 Last 12 Hours

# %%
# Kedro Catalog
pm25_last_hour = catalog.load('pm25_last_hour')
# Data Frame Sensors
pm25_last_hour.head()
# Out:
# 2022-09-21 23:16:50,697 - kedro.io.data_catalog - INFO - Loading data from `pm25_last_hour` (CSVDataSet)...
#                     DATETIME  TANGARA_2BBA  TANGARA_14D6  TANGARA_1CE2  \
# 0  2022-09-20T23:59:30-05:00      6.512605      6.112069      6.282051
# 1  2022-09-21T00:59:30-05:00      8.698276      7.344538      7.203390
# 2  2022-09-21T01:59:30-05:00      7.350000      8.869048      5.864407
# 3  2022-09-21T02:59:30-05:00      5.991597      7.127119      6.440678
# 4  2022-09-21T03:59:30-05:00      5.808333      7.982456      6.567797
#
#    TANGARA_1FCA  TANGARA_2492  TANGARA_2FF6  TANGARA_48C6  TANGARA_4D7A  \
# 0      6.743590      5.678261      6.336207      9.700855      0.487179
# 1      8.831933      4.666667      5.731092      8.086207      0.457627
# 2      7.818966      4.474576      5.230769      6.846154      0.075000
# 3      7.529412      5.059829      4.572650      5.711864      0.210084
# 4      7.855932      3.677966      4.456140      5.361345      0.092437
#
#    TANGARA_532E  TANGARA_EA06  TANGARA_F1AE  TANGARA_FAC6  TANGARA_06BE
# 0      3.000000      0.614035      6.709402      1.247863      7.155172
# 1      0.678571      0.525424      8.572650      1.067227      7.109244
# 2      4.552632      4.225000     11.808333      3.308333      9.504202
# 3      1.469027      0.872881     10.358974      1.313559      5.601695
# 4      1.771930      1.608333     20.600000      2.058333      5.403361

# %%
# Check Data Types
pm25_last_hour.dtypes
# Out:
# DATETIME         object
# TANGARA_2BBA    float64
# TANGARA_14D6    float64
# TANGARA_1CE2    float64
# TANGARA_1FCA    float64
# TANGARA_2492    float64
# TANGARA_2FF6    float64
# TANGARA_48C6    float64
# TANGARA_4D7A    float64
# TANGARA_532E    float64
# TANGARA_EA06    float64
# TANGARA_F1AE    float64
# TANGARA_FAC6    float64
# TANGARA_06BE    float64
# dtype: object

# %% [markdown]
# ## Descriptive Statistics

# %%
# Describe Data
pm25_last_hour.describe()
# Out:
#        TANGARA_2BBA  TANGARA_14D6  TANGARA_1CE2  TANGARA_1FCA  TANGARA_2492  \
# count     24.000000     24.000000     24.000000     24.000000     24.000000
# mean      10.605600      9.504180      8.702728     11.133779      9.859681
# std        4.047581      2.286113      2.494554      2.832977      4.040994
# min        5.808333      6.112069      5.144068      6.743590      3.616071
# 25%        8.360609      7.886415      6.539883      8.691176      5.602713
# 50%        9.243133      9.358345      8.062593     11.574875     10.891908
# 75%       11.487500     10.430929     10.116906     12.819666     12.153424
# max       20.000000     14.769231     14.000000     17.753846     16.763158
#
#        TANGARA_2FF6  TANGARA_48C6  TANGARA_4D7A  TANGARA_532E  TANGARA_EA06  \
# count     24.000000     24.000000     18.000000     24.000000     24.000000
# mean      10.304153     11.375229      1.853578      7.745003     15.618200
# std        4.281738      5.088223      1.523418      4.756257     11.549010
# min        4.221239      5.361345      0.060345      0.678571      0.525424
# 25%        6.184928      8.232078      0.420929      3.107143      4.283141
# 50%       10.812781      9.733036      1.833686      9.588054     20.024894
# 75%       12.856838     11.811995      3.142921     11.634084     24.839161
# max       18.774775     23.440000      3.775000     15.350877     33.558333
#
#        TANGARA_F1AE  TANGARA_FAC6  TANGARA_06BE
# count     24.000000     21.000000     24.000000
# mean      17.183352      8.781838     12.679593
# std        5.391263      6.436804      5.429801
# min        6.709402      1.067227      4.863248
# 25%       14.316810      3.308333      8.916944
# 50%       16.039186      6.125000     12.378318
# 75%       20.603017     14.516949     17.013513
# max       28.305085     18.924370     24.409091

# %%
# Plot Histograms
aqi.histplots(pm25_last_hour)

# %%
# Plot Boxplots
aqi.boxplots(pm25_last_hour)

# %%
# Get pm25 resample mean last 12 hours
def resample_pm25_last_12h(data_sensors):
    # Timestamp Format
    data_sensors['DATETIME'] = pd.to_datetime(data_sensors['DATETIME'])
    data_sensors = data_sensors.resample('12H', on='DATETIME', origin='end').mean().reset_index()#.median().reset_index()
    data_sensors['DATETIME'] = data_sensors['DATETIME'].apply(lambda x: x.isoformat())
    return data_sensors

# %%
# PM25 Last Hour
pm25_last_hour.tail()
# Out:
#                      DATETIME  TANGARA_2BBA  TANGARA_14D6  TANGARA_1CE2  \
# 19  2022-09-21T18:59:30-05:00     13.325000     10.441667     11.641026
# 20  2022-09-21T19:59:30-05:00     14.796610     10.696429     13.114286
# 21  2022-09-21T20:59:30-05:00     17.714286     13.472973     12.051282
# 22  2022-09-21T21:59:30-05:00     19.000000     12.752381     12.726316
# 23  2022-09-21T22:59:30-05:00     20.000000     14.769231     14.000000
#
#     TANGARA_1FCA  TANGARA_2492  TANGARA_2FF6  TANGARA_48C6  TANGARA_4D7A  \
# 19     11.765217     12.110169     13.786325     10.025210           NaN
# 20     12.982759     14.798246     14.875000     13.239130           NaN
# 21     13.889831     16.763158     15.474138      9.605042           NaN
# 22     15.529915     15.194915     11.831933     18.307692           NaN
# 23     17.753846     15.589744     15.873950      7.965812           NaN
#
#     TANGARA_532E  TANGARA_EA06  TANGARA_F1AE  TANGARA_FAC6  TANGARA_06BE
# 19     12.168142     24.915966     19.598291           NaN     16.873950
# 20     12.389381     24.517857     21.418803           NaN     18.274336
# 21      6.218487      9.747826     15.747899      6.125000     21.048193
# 22      3.837838      6.529915     12.722689      4.983193     11.956897
# 23      3.142857      4.302521     20.612069      3.872881     24.409091

# %%
# PM25 Last 12 Hours
pm25_last_12h = resample_pm25_last_12h(pm25_last_hour)
pm25_last_12h.head()
# Out:
#                     DATETIME  TANGARA_2BBA  TANGARA_14D6  TANGARA_1CE2  \
# 0  2022-09-21T10:59:30-05:00      8.493098      7.956249      7.162222
# 1  2022-09-21T22:59:30-05:00     12.718101     11.052112     10.243234
#
#    TANGARA_1FCA  TANGARA_2492  TANGARA_2FF6  TANGARA_48C6  TANGARA_4D7A  \
# 0      9.159721      7.170193      8.040285     12.335122      1.048912
# 1     13.107837     12.549170     12.568020     10.415336      3.462910
#
#    TANGARA_532E  TANGARA_EA06  TANGARA_F1AE  TANGARA_FAC6  TANGARA_06BE
# 0      5.710261     10.022022     17.631801      6.220140     10.321593
# 1      9.779745     21.214378     16.734903     12.197435     15.037593

# %%
# Describe Data
pm25_last_hour.describe()
# Out:
#        TANGARA_2BBA  TANGARA_14D6  TANGARA_1CE2  TANGARA_1FCA  TANGARA_2492  \
# count     24.000000     24.000000     24.000000     24.000000     24.000000
# mean      10.605600      9.504180      8.702728     11.133779      9.859681
# std        4.047581      2.286113      2.494554      2.832977      4.040994
# min        5.808333      6.112069      5.144068      6.743590      3.616071
# 25%        8.360609      7.886415      6.539883      8.691176      5.602713
# 50%        9.243133      9.358345      8.062593     11.574875     10.891908
# 75%       11.487500     10.430929     10.116906     12.819666     12.153424
# max       20.000000     14.769231     14.000000     17.753846     16.763158
#
#        TANGARA_2FF6  TANGARA_48C6  TANGARA_4D7A  TANGARA_532E  TANGARA_EA06  \
# count     24.000000     24.000000     18.000000     24.000000     24.000000
# mean      10.304153     11.375229      1.853578      7.745003     15.618200
# std        4.281738      5.088223      1.523418      4.756257     11.549010
# min        4.221239      5.361345      0.060345      0.678571      0.525424
# 25%        6.184928      8.232078      0.420929      3.107143      4.283141
# 50%       10.812781      9.733036      1.833686      9.588054     20.024894
# 75%       12.856838     11.811995      3.142921     11.634084     24.839161
# max       18.774775     23.440000      3.775000     15.350877     33.558333
#
#        TANGARA_F1AE  TANGARA_FAC6  TANGARA_06BE
# count     24.000000     21.000000     24.000000
# mean      17.183352      8.781838     12.679593
# std        5.391263      6.436804      5.429801
# min        6.709402      1.067227      4.863248
# 25%       14.316810      3.308333      8.916944
# 50%       16.039186      6.125000     12.378318
# 75%       20.603017     14.516949     17.013513
# max       28.305085     18.924370     24.409091

# %%
# Describe Data
pm25_last_12h.describe()
# Out:
#        TANGARA_2BBA  TANGARA_14D6  TANGARA_1CE2  TANGARA_1FCA  TANGARA_2492  \
# count      2.000000      2.000000      2.000000      2.000000      2.000000
# mean      10.605600      9.504180      8.702728     11.133779      9.859681
# std        2.987528      2.189105      2.178605      2.791739      3.803511
# min        8.493098      7.956249      7.162222      9.159721      7.170193
# 25%        9.549349      8.730215      7.932475     10.146750      8.514937
# 50%       10.605600      9.504180      8.702728     11.133779      9.859681
# 75%       11.661851     10.278146      9.472981     12.120808     11.204426
# max       12.718101     11.052112     10.243234     13.107837     12.549170
#
#        TANGARA_2FF6  TANGARA_48C6  TANGARA_4D7A  TANGARA_532E  TANGARA_EA06  \
# count      2.000000      2.000000      2.000000      2.000000      2.000000
# mean      10.304153     11.375229      2.255911      7.745003     15.618200
# std        3.201592      1.357494      1.706954      2.877560      7.914191
# min        8.040285     10.415336      1.048912      5.710261     10.022022
# 25%        9.172219     10.895282      1.652412      6.727632     12.820111
# 50%       10.304153     11.375229      2.255911      7.745003     15.618200
# 75%       11.436086     11.855176      2.859411      8.762374     18.416289
# max       12.568020     12.335122      3.462910      9.779745     21.214378
#
#        TANGARA_F1AE  TANGARA_FAC6  TANGARA_06BE
# count      2.000000      2.000000      2.000000
# mean      17.183352      9.208787     12.679593
# std        0.634203      4.226586      3.334716
# min       16.734903      6.220140     10.321593
# 25%       16.959127      7.714463     11.500593
# 50%       17.183352      9.208787     12.679593
# 75%       17.407577     10.703111     13.858593
# max       17.631801     12.197435     15.037593

# %%
# Plot Histograms
aqi.histplots(pm25_last_12h)

# %%
# Plot Boxplots
aqi.boxplots(pm25_last_12h)

# %%
# Plot Lineplots
aqi.lineplots(pm25_last_12h)

# %%
# Save pm25_last_12h into Catalog
catalog.save('pm25_last_12h', pm25_last_12h)
# Out:
# 2022-09-21 23:17:32,729 - kedro.io.data_catalog - INFO - Saving data to `pm25_last_12h` (CSVDataSet)...
