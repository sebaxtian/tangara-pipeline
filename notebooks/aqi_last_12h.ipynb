# %%
import pandas as pd
import numpy as np
import requests
from datetime import datetime, timezone, timedelta
from io import StringIO
import geohash2
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import math
# Gloabl seaborn Theme
sns.set_theme(style="whitegrid", palette="pastel")
import import_ipynb
import pm25_nowcast_aqi as aqi
# Out:
# importing Jupyter notebook from pm25_nowcast_aqi.ipynb
# PM25: 35.9 AQI: 102

# %% [markdown]
# ## Extraction - AQI Last 12 Hours

# %%
# Kedro Catalog
pm25_last_12h = catalog.load('pm25_last_12h')
# Data Frame Sensors
pm25_last_12h.head()
# Out:
# 2022-09-10 16:55:53,144 - kedro.io.data_catalog - INFO - Loading data from `pm25_last_12h` (CSVDataSet)...
#                     DATETIME  TANGARA_2BBA  TANGARA_14D6  TANGARA_1CE2  \
# 0  2022-09-06 01:34:30-05:00     19.347478     23.165593     23.595339
# 1  2022-09-06 13:34:30-05:00     23.275584     25.277034     26.844065
#
#    TANGARA_1FCA  TANGARA_2492  TANGARA_2FF6  TANGARA_48C6  TANGARA_4D7A  \
# 0     28.575207     23.402513     23.734368     12.624426      4.112644
# 1           NaN     29.940656     29.354339     20.027175      7.145834
#
#    TANGARA_532E  TANGARA_EA06  TANGARA_F1AE  TANGARA_FAC6  TANGARA_06BE
# 0     11.130586     22.051994     24.085174     15.159342     23.052585
# 1     21.357261     42.260197     32.573870     27.737214     28.257776

# %%
# Check Data Types
pm25_last_12h.dtypes
# Out:
# DATETIME         object
# TANGARA_2BBA    float64
# TANGARA_14D6    float64
# TANGARA_1CE2    float64
# TANGARA_1FCA    float64
# TANGARA_2492    float64
# TANGARA_2FF6    float64
# TANGARA_48C6    float64
# TANGARA_4D7A    float64
# TANGARA_532E    float64
# TANGARA_EA06    float64
# TANGARA_F1AE    float64
# TANGARA_FAC6    float64
# TANGARA_06BE    float64
# dtype: object

# %%
# Data Frame AQI Last 12 Hours
aqi_last_12h = aqi.pm25_to_aqi(pm25_last_12h)
aqi_last_12h.head()
# Out:
#                     DATETIME  TANGARA_2BBA  TANGARA_14D6  TANGARA_1CE2  \
# 0  2022-09-06 01:34:30-05:00            67            75            76
# 1  2022-09-06 13:34:30-05:00            75            79            82
#
#    TANGARA_1FCA  TANGARA_2492  TANGARA_2FF6  TANGARA_48C6  TANGARA_4D7A  \
# 0          86.0            75            76            53            18
# 1           NaN            89            88            68            30
#
#    TANGARA_532E  TANGARA_EA06  TANGARA_F1AE  TANGARA_FAC6  TANGARA_06BE
# 0            47            73            77            58            75
# 1            71           118            95            84            86

# %%
# Describe Data
pm25_last_12h.describe()
# Out:
#        TANGARA_2BBA  TANGARA_14D6  TANGARA_1CE2  TANGARA_1FCA  TANGARA_2492  \
# count      2.000000      2.000000      2.000000      1.000000      2.000000
# mean      21.311531     24.221313     25.219702     28.575207     26.671584
# std        2.777591      1.493014      2.297196           NaN      4.623165
# min       19.347478     23.165593     23.595339     28.575207     23.402513
# 25%       20.329504     23.693453     24.407521     28.575207     25.037049
# 50%       21.311531     24.221313     25.219702     28.575207     26.671584
# 75%       22.293557     24.749174     26.031884     28.575207     28.306120
# max       23.275584     25.277034     26.844065     28.575207     29.940656
#
#        TANGARA_2FF6  TANGARA_48C6  TANGARA_4D7A  TANGARA_532E  TANGARA_EA06  \
# count      2.000000      2.000000      2.000000      2.000000      2.000000
# mean      26.544354     16.325800      5.629239     16.243923     32.156095
# ...

# %%
# Describe Data
aqi_last_12h.describe()
# Out:
#        TANGARA_2BBA  TANGARA_14D6  TANGARA_1CE2  TANGARA_1FCA  TANGARA_2492  \
# count      2.000000      2.000000      2.000000           1.0      2.000000
# mean      71.000000     77.000000     79.000000          86.0     82.000000
# std        5.656854      2.828427      4.242641           NaN      9.899495
# min       67.000000     75.000000     76.000000          86.0     75.000000
# 25%       69.000000     76.000000     77.500000          86.0     78.500000
# 50%       71.000000     77.000000     79.000000          86.0     82.000000
# 75%       73.000000     78.000000     80.500000          86.0     85.500000
# max       75.000000     79.000000     82.000000          86.0     89.000000
#
#        TANGARA_2FF6  TANGARA_48C6  TANGARA_4D7A  TANGARA_532E  TANGARA_EA06  \
# count      2.000000      2.000000      2.000000      2.000000      2.000000
# mean      82.000000     60.500000     24.000000     59.000000     95.500000
# ...

# %%
# Plot Histograms
aqi.histplots(aqi_last_12h)

# %%
# Plot Boxplots
aqi.boxplots(aqi_last_12h)

# %%
# Plot Lineplots
aqi.lineplots(aqi_last_12h)

# %%
# Save aqi_last_12h into Catalog
catalog.save('aqi_last_12h', aqi_last_12h)
# Out:
# 2022-09-10 16:56:18,907 - kedro.io.data_catalog - INFO - Saving data to `aqi_last_12h` (CSVDataSet)...
